# %% [markdown]
# # Introduction

# %% [markdown]
# Airbnb is an online marketplace for arranging or offering lodging, primarily homestays, or tourism experiences. Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities. It renders an unique and personalized way of experiencing the world and socializing with new people. This dataset describes the listing activity and metrics in Boston, MA for 2019. This data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions. What can we learn about AirBnB rentals if we try to model their price?
# The analysis could provide some insights on:
# 1. What features affect the price? By how much?
# 2. The popular description words in different price groups.

# %% [markdown]
# ## Import packages and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# %matplotlib inline
sns.set_style('darkgrid')

# %%
# import data to dataframes
list_df = pd.read_csv('listings.csv')

# %% [markdown]
# # EDA

# %%
list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   scrape_id                         3585 non-null   int64
#  3   last_scraped                      3585 non-null   object
#  4   name                              3585 non-null   object
#  5   summary                           3442 non-null   object
#  6   space                             2528 non-null   object
#  7   description                       3585 non-null   object
#  8   experiences_offered               3585 non-null   object
#  9   neighborhood_overview             2170 non-null   object
#  10  notes                             1610 non-null   object
#  11  transit                           2295 non-null   object
#  12  access                            2096 non-null   object
#  13  interaction                       2031 non-null   object
#  14  house_rules                       2393 non-null   object
#  15  thumbnail_url                     2986 non-null   object
#  16  medium_url                        2986 non-null   object
#  17  picture_url                       3585 non-null   object
#  18  xl_picture_url                    2986 non-null   object
#  19  host_id                           3585 non-null   int64
#  20  host_url                          3585 non-null   object
#  21  host_name                         3585 non-null   object
#  22  host_since                        3585 non-null   object
#  23  host_location                     3574 non-null   object
#  24  host_about                        2276 non-null   object
#  25  host_response_time                3114 non-null   object
#  26  host_response_rate                3114 non-null   object
#  27  host_acceptance_rate              3114 non-null   object
#  28  host_is_superhost                 3585 non-null   object
#  29  host_thumbnail_url                3585 non-null   object
#  30  host_picture_url                  3585 non-null   object
#  31  host_neighbourhood                3246 non-null   object
#  32  host_listings_count               3585 non-null   int64
#  33  host_total_listings_count         3585 non-null   int64
#  34  host_verifications                3585 non-null   object
#  35  host_has_profile_pic              3585 non-null   object
#  36  host_identity_verified            3585 non-null   object
#  37  street                            3585 non-null   object
#  38  neighbourhood                     3042 non-null   object
#  39  neighbourhood_cleansed            3585 non-null   object
#  40  neighbourhood_group_cleansed      0 non-null      float64
#  41  city                              3583 non-null   object
#  42  state                             3585 non-null   object
#  43  zipcode                           3547 non-null   object
#  44  market                            3571 non-null   object
#  45  smart_location                    3585 non-null   object
#  46  country_code                      3585 non-null   object
#  47  country                           3585 non-null   object
#  48  latitude                          3585 non-null   float64
#  49  longitude                         3585 non-null   float64
#  50  is_location_exact                 3585 non-null   object
#  51  property_type                     3582 non-null   object
#  52  room_type                         3585 non-null   object
#  53  accommodates                      3585 non-null   int64
#  54  bathrooms                         3571 non-null   float64
#  55  bedrooms                          3575 non-null   float64
#  56  beds                              3576 non-null   float64
#  57  bed_type                          3585 non-null   object
#  58  amenities                         3585 non-null   object
#  59  square_feet                       56 non-null     float64
#  60  price                             3585 non-null   object
#  61  weekly_price                      892 non-null    object
#  62  monthly_price                     888 non-null    object
#  63  security_deposit                  1342 non-null   object
#  64  cleaning_fee                      2478 non-null   object
#  65  guests_included                   3585 non-null   int64
#  66  extra_people                      3585 non-null   object
#  67  minimum_nights                    3585 non-null   int64
#  68  maximum_nights                    3585 non-null   int64
#  69  calendar_updated                  3585 non-null   object
#  70  has_availability                  0 non-null      float64
#  71  availability_30                   3585 non-null   int64
#  72  availability_60                   3585 non-null   int64
#  73  availability_90                   3585 non-null   int64
#  74  availability_365                  3585 non-null   int64
#  75  calendar_last_scraped             3585 non-null   object
#  76  number_of_reviews                 3585 non-null   int64
#  77  first_review                      2829 non-null   object
#  78  last_review                       2829 non-null   object
#  79  review_scores_rating              2772 non-null   float64
#  80  review_scores_accuracy            2762 non-null   float64
#  81  review_scores_cleanliness         2767 non-null   float64
#  82  review_scores_checkin             2765 non-null   float64
#  83  review_scores_communication       2767 non-null   float64
#  84  review_scores_location            2763 non-null   float64
#  85  review_scores_value               2764 non-null   float64
#  86  requires_license                  3585 non-null   object
#  87  license                           0 non-null      float64
#  88  jurisdiction_names                0 non-null      float64
#  89  instant_bookable                  3585 non-null   object
#  90  cancellation_policy               3585 non-null   object
#  91  require_guest_profile_picture     3585 non-null   object
#  92  require_guest_phone_verification  3585 non-null   object
#  93  calculated_host_listings_count    3585 non-null   int64
#  94  reviews_per_month                 2829 non-null   float64
# dtypes: float64(18), int64(15), object(62)
# memory usage: 2.6+ MB

# %%
# Copy the dataframe
list_clean = list_df.copy()

# %%
# First, let's drop some columns that are not useful for analysis
cols = ['thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'listing_url', 'host_url',
       'host_thumbnail_url', 'host_picture_url', 'country', 'country_code', 'neighbourhood',
       'smart_location', 'street', 'market', 'first_review', 'last_review', 'state', 'calendar_last_scraped',
       'calendar_updated', 'city', 'scrape_id', 'last_scraped', 'space', 'host_neighbourhood', 
        'neighborhood_overview', 'host_listings_count', 'zipcode', 'is_location_exact', 'host_location',
       'host_total_listings_count']
list_clean.drop(cols, axis=1, inplace=True)

# %%
list_clean.isnull().sum().sort_values(ascending=False)
# Out:
# has_availability                  3585
# jurisdiction_names                3585
# license                           3585
# neighbourhood_group_cleansed      3585
# square_feet                       3529
#                                   ...
# calculated_host_listings_count       0
# bed_type                             0
# accommodates                         0
# room_type                            0
# id                                   0
# Length: 65, dtype: int64

# %%
# drop the colunms with more than half of the missing value
cols = list_clean.columns[list_clean.isnull().sum()/list_clean.shape[0] > 0.5]
list_clean.drop(cols, axis=1, inplace=True)

# %%
# We are going to use the price to predict, so drop any rows in price with missing value
list_clean.dropna(axis=0, subset=['price'], inplace=True)

# %%
# Next, let's fix some datatype errors, extract numbers and change to int type
cols = ['host_response_rate', 'host_acceptance_rate', 'price', 'cleaning_fee', 'extra_people']
for col in cols:
    list_clean[col] = list_clean[col].str.extract(r'(\d+)')
    list_clean[col] = list_clean[col].astype('float128').astype('Int64')
list_clean[cols].dtypes
# Out:
# host_response_rate      Int64
# host_acceptance_rate    Int64
# price                   Int64
# cleaning_fee            Int64
# extra_people            Int64
# dtype: object

# %%
# Change datatype for host_since
list_clean['host_since'] = pd.to_datetime(list_clean.host_since)
temp = pd.to_datetime('12/31/2019')

# %%
list_clean['host_len'] = list_clean.host_since.apply(lambda x: pd.Timedelta(temp-x).days)
list_clean = list_clean.drop('host_since', axis=1)

# %%
# extract the number of amenities 
list_clean['n_amenities'] = list_clean['amenities'].apply(lambda x: len(x.replace('{', '').\
                        replace('{', '').replace('"', '').split(',')))
list_clean.drop('amenities', axis=1, inplace=True)

# %%
df_num = list_clean.select_dtypes(include=['int', 'float'])
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3585 entries, 0 to 3584
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3585 non-null   int64
#  1   host_id                         3585 non-null   int64
#  2   host_response_rate              3114 non-null   Int64
#  3   host_acceptance_rate            3114 non-null   Int64
#  4   latitude                        3585 non-null   float64
#  5   longitude                       3585 non-null   float64
#  6   accommodates                    3585 non-null   int64
#  7   bathrooms                       3571 non-null   float64
#  8   bedrooms                        3575 non-null   float64
#  9   beds                            3576 non-null   float64
#  10  price                           3585 non-null   Int64
#  11  cleaning_fee                    2478 non-null   Int64
#  12  guests_included                 3585 non-null   int64
#  13  extra_people                    3585 non-null   Int64
#  14  minimum_nights                  3585 non-null   int64
#  15  maximum_nights                  3585 non-null   int64
#  16  availability_30                 3585 non-null   int64
#  17  availability_60                 3585 non-null   int64
#  18  availability_90                 3585 non-null   int64
#  19  availability_365                3585 non-null   int64
#  20  number_of_reviews               3585 non-null   int64
#  21  review_scores_rating            2772 non-null   float64
#  22  review_scores_accuracy          2762 non-null   float64
#  23  review_scores_cleanliness       2767 non-null   float64
#  24  review_scores_checkin           2765 non-null   float64
#  25  review_scores_communication     2767 non-null   float64
#  26  review_scores_location          2763 non-null   float64
#  27  review_scores_value             2764 non-null   float64
#  28  calculated_host_listings_count  3585 non-null   int64
#  29  reviews_per_month               2829 non-null   float64
#  30  host_len                        3585 non-null   int64
#  31  n_amenities                     3585 non-null   int64
# dtypes: Int64(5), float64(13), int64(14)
# memory usage: 941.8 KB

# %%
# fill na for the columns
int_fillmean = lambda x: x.fillna(round(x.mean()))
df_num = df_num.apply(int_fillmean, axis=0)
df_num = df_num.drop(['id', 'host_id', 'latitude', 'longitude'], axis=1).astype(float)

# %%
df_num.describe()
# Out:
#        host_response_rate  host_acceptance_rate  accommodates    bathrooms  \
# count         3585.000000           3585.000000   3585.000000  3585.000000
# mean            94.990516             84.150349      3.041283     1.220781
# std             11.666206             20.297865      1.778929     0.500698
# min              0.000000              0.000000      1.000000     0.000000
# 25%             95.000000             79.000000      2.000000     1.000000
# 50%            100.000000             91.000000      2.000000     1.000000
# 75%            100.000000            100.000000      4.000000     1.000000
# max            100.000000            100.000000     16.000000     6.000000
#
#           bedrooms         beds        price  cleaning_fee  guests_included  \
# count  3585.000000  3585.000000  3585.000000   3585.000000      3585.000000
# mean      1.255230     1.610042   168.511576     68.262762         1.429847
# std       0.752129     1.010663   111.909788     42.646336         1.056787
# min       0.000000     0.000000     1.000000      5.000000         0.000000
# 25%       1.000000     1.000000    85.000000     40.000000         1.000000
# 50%       1.000000     1.000000   150.000000     68.000000         1.000000
# 75%       2.000000     2.000000   220.000000     80.000000         1.000000
# max       5.000000    16.000000   999.000000    300.000000        14.000000
#
#        extra_people  ...  review_scores_accuracy  review_scores_cleanliness  \
# count   3585.000000  ...             3585.000000                3585.000000
# mean      10.886192  ...                9.332497                   9.199163
# std       19.137773  ...                0.837804                   1.032642
# min        0.000000  ...                2.000000                   2.000000
# 25%        0.000000  ...                9.000000                   9.000000
# 50%        0.000000  ...                9.000000                   9.000000
# 75%       20.000000  ...               10.000000                  10.000000
# max      200.000000  ...               10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            3585.000000                  3585.000000
# mean                9.727197                     9.727197
# std                 0.686118                     0.662954
# min                 2.000000                     4.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             3585.000000          3585.000000
# mean                 9.319107             9.129707
# std                  0.811975             0.890595
# min                  2.000000             2.000000
# 25%                  9.000000             9.000000
# 50%                  9.000000             9.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month     host_len  \
# count                     3585.000000        3585.000000  3585.000000
# mean                        12.733891           1.977043  2104.668340
# std                         29.415076           1.883715   620.783376
# min                          1.000000           0.010000  1211.000000
# 25%                          1.000000           0.640000  1653.000000
# 50%                          2.000000           1.910000  1975.000000
# 75%                          6.000000           2.130000  2440.000000
# max                        136.000000          19.150000  4067.000000
#
#        n_amenities
# count  3585.000000
# mean     15.862762
# std       4.832590
# min       1.000000
# 25%      13.000000
# 50%      16.000000
# 75%      19.000000
# max      31.000000
#
# [8 rows x 28 columns]

# %%
# visualizae the price
plt.figure(figsize=(8, 6))
sns.distplot(df_num['price'], bins=50, kde=True)
plt.ylabel('Percentage', fontsize=12)
plt.xlabel('Price (dollar)', fontsize=12)
plt.title('Listed Price Distribution', fontsize=14);

# %%
# we can see that some listed price are 1 dollar, which is not intuitive
df_num = df_num[df_num['price'] != 1]

# %%
# we will also exlude some outliers of the price > 1.5 IQR
df_num = df_num[df_num['price'] < 423]

# %%
# visualize the correlation matrix
corr = df_num.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(18, 16))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True, fmt='.2f', cmap='coolwarm')

# %%
# Next select coloumns with fair correlations with the price 
corr_list = df_num.drop('price', axis=1).apply(lambda x: x.corr(df_num['price']))
cols = []
for col in corr_list.index:
    if (corr_list[col]>0.3 or corr_list[col]<-0.3):
        cols.append(col)
cols
# Out:
# ['accommodates',
#  'bedrooms',
#  'beds',
#  'cleaning_fee',
#  'calculated_host_listings_count']

# %%
pd.plotting.scatter_matrix(df_num[cols], figsize=(16, 16), alpha=0.5);

# %%
# visualizae the price
plt.figure(figsize=(8, 6))
sns.heatmap(df_num.groupby(['bathrooms', 'bedrooms']).mean()['price'].reset_index()\
                .pivot('bathrooms', 'bedrooms', 'price').sort_index(ascending=False),
            cmap="coolwarm", fmt='.0f', annot=True, linewidths=0.5);

# %%
# Next let's look at the categorical values
df_cat = list_clean.select_dtypes(include=['object'])
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3585 entries, 0 to 3584
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   name                              3585 non-null   object
#  1   summary                           3442 non-null   object
#  2   description                       3585 non-null   object
#  3   experiences_offered               3585 non-null   object
#  4   transit                           2295 non-null   object
#  5   access                            2096 non-null   object
#  6   interaction                       2031 non-null   object
#  7   house_rules                       2393 non-null   object
#  8   host_name                         3585 non-null   object
#  9   host_about                        2276 non-null   object
#  10  host_response_time                3114 non-null   object
#  11  host_is_superhost                 3585 non-null   object
#  12  host_verifications                3585 non-null   object
#  13  host_has_profile_pic              3585 non-null   object
#  14  host_identity_verified            3585 non-null   object
#  15  neighbourhood_cleansed            3585 non-null   object
#  16  property_type                     3582 non-null   object
#  17  room_type                         3585 non-null   object
#  18  bed_type                          3585 non-null   object
#  19  requires_license                  3585 non-null   object
#  20  instant_bookable                  3585 non-null   object
#  21  cancellation_policy               3585 non-null   object
#  22  require_guest_profile_picture     3585 non-null   object
#  23  require_guest_phone_verification  3585 non-null   object
# dtypes: object(24)
# memory usage: 700.2+ KB

# %%
# we will drop few description lines for future analysis
df_cat = df_cat.drop(['name', 'summary', 'description', 'experiences_offered', 'host_about', 
                      'host_verifications', 'host_name'], axis=1)

# %% [markdown]
# I think interaction, house_rules, access can substantial the post. Maybe provide the information would attract more people and pontentially inrease the value of the house. Since there are a lot of missing values in these columns, I will just categorize them with t (with info) and f (without info).

# %%
# find the not na rows with True
df_cat['with_inter'] = df_cat.interaction.notna().astype('object')
df_cat['with_access']= df_cat.access.notna().astype('object')
df_cat['with_rules'] = df_cat.house_rules.notna().astype('object')
df_cat['with_transit'] = df_cat.transit.notna().astype('object')
df_cat = df_cat.drop(['transit', 'access', 'interaction', 'house_rules'], axis=1)

# %%
df_cat = pd.concat([df_cat, list_clean.price], axis=1)
df_cat = df_cat[df_cat['price'] != 1]
df_cat = df_cat[df_cat['price'] < 423]
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 0 to 3584
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   host_response_time                3019 non-null   object
#  1   host_is_superhost                 3463 non-null   object
#  2   host_has_profile_pic              3463 non-null   object
#  3   host_identity_verified            3463 non-null   object
#  4   neighbourhood_cleansed            3463 non-null   object
#  5   property_type                     3460 non-null   object
#  6   room_type                         3463 non-null   object
#  7   bed_type                          3463 non-null   object
#  8   requires_license                  3463 non-null   object
#  9   instant_bookable                  3463 non-null   object
#  10  cancellation_policy               3463 non-null   object
#  11  require_guest_profile_picture     3463 non-null   object
#  12  require_guest_phone_verification  3463 non-null   object
#  13  with_inter                        3463 non-null   object
#  14  with_access                       3463 non-null   object
#  15  with_rules                        3463 non-null   object
#  16  with_transit                      3463 non-null   object
#  17  price                             3463 non-null   Int64
# dtypes: Int64(1), object(17)
# memory usage: 517.4+ KB

# %%
# visualize different room type
plt.figure(figsize=(8, 6))
sns.barplot(data=df_cat, x='room_type', y='price', color=sns.color_palette()[0]);
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Price (dollar)', fontsize=12)
plt.title('Price for Different Room Types', fontsize=14);

# %%
# visualize different cancellation policy
plt.figure(figsize=(8, 6))
sns.barplot(data=df_cat, x='cancellation_policy', y='price', color=sns.color_palette()[0]);
plt.xlabel('Cancellation Policy', fontsize=12)
plt.ylabel('Price (dollar)', fontsize=12)
plt.title('Price for Different Cancellation Policy', fontsize=14);

# %%
# visualize different neighbourhood
temp = df_cat.groupby(['neighbourhood_cleansed'])['price'].mean().sort_values(ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x=temp.index, y=temp.values, palette=sns.color_palette('PuBuGn_d'));
plt.xlabel('Neighbourhood', fontsize=12)
plt.ylabel('Price (dollar)', fontsize=12)
plt.title('Price for Different Neighbourhoods', fontsize=14)
plt.xticks(rotation=60);

# %%
# get dummy values for categorical features
df_cat_dummies = pd.get_dummies(df_cat.iloc[:,:-1], dummy_na=False)

# %%
# concatenate the model df
df_mod = pd.concat([df_num, df_cat_dummies], axis=1)

# %% [markdown]
# # Popular Word and Word Cloud

# %% [markdown]
# ## Popular words

# %%
# We will first extract the dataframe for word analysis
df_word = list_clean.loc[:,['description', 'price']]
df_word = df_word[df_word.price!=1] 
df_word = df_word[df_word.price<423] 
df_word.sample(5)
# Out:
#                                             description  price
# 2884  Double bed. Quiet street. 7min walk to JFK-UMa...     50
# 766   Our spacious open loft in a historic building ...    150
# 1756  Penthouse three bed, two bath duplex with pano...    315
# 195   Private room and bath. We are offering a light...     80
# 45    Guest room available in cozy, well-lit home on...     45

# %%
# We will next extract the dataframe for different neighbourhood 
df_n = list_clean.loc[:,['description', 'neighbourhood_cleansed']]
df_n.sample(5)
# Out:
#                                             description  \
# 123   Our place is a clean, comfortable, and beautif...
# 103   My wife and i are empy nesters who enjoy meeti...
# 3095  Spacious 1BR in brand new luxury apartment bui...
# 813   Now called the South End, it is formerly Roxbu...
# 1438  5th floor Victorian brownstone on Beacon St / ...
#
#        neighbourhood_cleansed
# 123             Jamaica Plain
# 103             Jamaica Plain
# 3095  South Boston Waterfront
# 813                   Roxbury
# 1438                 Back Bay

# %%
df_word['price'].describe()
# Out:
# count    3463.000000
# mean      156.593705
# std        86.893926
# min         3.000000
# 25%        84.000000
# 50%       145.000000
# 75%       205.500000
# max       417.000000
# Name: price, dtype: float64

# %%
# segment price into two groups 
bin_edges = [0, 84, 145, 205, 417]
bin_name = ['25%', '50%', '75%', '100%']
df_word['price_bin'] = pd.cut(df_word['price'], bins=bin_edges, labels=bin_name)

# %%
# get the post content for different neighborhood group
n_words = {};
n_list = df_n.neighbourhood_cleansed.unique()
for i in range(len(n_list)):
    n_words[i] = ''
    df_i = df_n[df_n['neighbourhood_cleansed'] == n_list[i]]['description'].astype(str)
    for j in range(len(df_i)):
        words = df_i.iloc[j].split(' ')
        for word in words:
            n_words[i] += word+' '

# %%
# get the post content for each price group
p_words = {};
for i in range(len(bin_name)):
    p_words[i] = ''
    df_i = df_word[df_word['price_bin'] == bin_name[i]]['description'].astype(str)
    for j in range(len(df_i)):
        words = df_i.iloc[j].split(' ')
        for word in words:
            p_words[i] += word+' '

# %%
# Get the most popular 20 words for each price group 
from collections import Counter
import string
counter = {}
occur = {}
stop_words = ['a', 'the', 'and', 'is', 'of', 'with', '', 'in', 'i', 'you', 'for', 'on', 'at', 'this', 'there', 
              'that', 'to', 'from', 'have', 'has', 'we', 'your', 'my', 'are', 'be', 'or', 'will', 'our', 'it',
             'located', 'all', 'as']
for i in range(len(bin_name)):
    words = p_words[i].lower().translate(str.maketrans('', '', string.punctuation)).split(' ')
    counter[i] = Counter([word for word in words if word not in stop_words])
    occur[i] = counter[i].most_common(20)
    
df1 = pd.DataFrame.from_dict(occur[0]).rename(columns={0:'word', 1:'count'})
df2 = pd.DataFrame.from_dict(occur[1]).rename(columns={0:'word', 1:'count'})
df3 = pd.DataFrame.from_dict(occur[2]).rename(columns={0:'word', 1:'count'})
df4 = pd.DataFrame.from_dict(occur[3]).rename(columns={0:'word', 1:'count'})

# %%
pd.DataFrame.from_dict(occur).rename(columns={0:'0%-25%', 1:'25%-50%', 2:'50%-75%', 3:'75%-100%'})
# Out:
#                  0%-25%             25%-50%             50%-75%  \
# 0          (room, 1389)      (boston, 1065)      (boston, 1145)
# 1         (boston, 862)         (room, 952)    (apartment, 916)
# 2        (kitchen, 673)    (apartment, 740)      (kitchen, 636)
# 3           (walk, 627)         (walk, 680)         (walk, 605)
# 4      (apartment, 536)      (kitchen, 621)      (bedroom, 600)
# 5          (house, 504)      (bedroom, 591)         (room, 575)
# 6         (access, 451)      (private, 550)          (bed, 522)
# 7           (line, 450)          (bed, 528)          (one, 489)
# 8            (bed, 448)       (access, 480)       (street, 484)
# 9          (place, 441)     (bathroom, 437)       (living, 451)
# 10      (bathroom, 437)     (downtown, 436)        (floor, 422)
# 11        (living, 436)       (living, 408)       (access, 408)
# 12      (downtown, 418)       (street, 408)  (restaurants, 402)
# 13          (home, 413)          (one, 408)          (end, 398)
# 14       (bedroom, 407)            (2, 382)      (private, 372)
# 15       (private, 403)         (area, 368)         (full, 355)
# 16           (bus, 377)  (restaurants, 366)            (2, 348)
# 17          (very, 375)         (line, 359)          (two, 337)
# 18  (neighborhood, 374)        (great, 343)        (place, 335)
# 19         (close, 373)        (place, 338)         (back, 332)
#
#               75%-100%
# 0       (boston, 1096)
# 1     (apartment, 975)
# 2       (kitchen, 643)
# 3       (bedroom, 627)
# 4          (room, 598)
# 5           (bed, 533)
# 6        (living, 508)
# 7             (•, 501)
# 8          (walk, 495)
# 9             (2, 422)
# 10        (floor, 401)
# 11          (one, 400)
# 12         (area, 393)
# 13          (two, 392)
# 14      (private, 384)
# 15  (restaurants, 381)
# 16        (queen, 378)
# 17         (full, 376)
# 18       (street, 370)
# 19         (unit, 366)

# %%
# visualization 
plt.figure(figsize=(20, 14))
plt.subplot(2, 2, 1)
ax1 = sns.barplot(data=df1, x='word', y='count', palette = 'RdBu')
plt.xticks(rotation=60)
plt.xlabel('')
plt.title('0%-25%', fontsize=12);

plt.subplot(2, 2, 2)
ax2 = sns.barplot(data=df2, x='word', y='count', palette = 'RdBu')
plt.xticks(rotation=60)
plt.xlabel('')
plt.title('25%-50%', fontsize=12)

plt.subplot(2, 2, 3)
ax2 = sns.barplot(data=df3, x='word', y='count', palette = 'RdBu')
plt.xticks(rotation=60)
plt.title('50%-75%', fontsize=12)

plt.subplot(2, 2, 4)
ax2 = sns.barplot(data=df4, x='word', y='count', palette = 'RdBu')
plt.xticks(rotation=60)
plt.title('75%-100%', fontsize=12)

plt.suptitle('Popular Words in Different Price Group');

# %% [markdown]
# There a a lot of overlapping in different price groups, one thing that is interesting is that the higher priced listings contains 'restuarants' more frequently, while lower price listings emphasize some transportation words such as 'bus' and 'line' (metro).

# %% [markdown]
# ## Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
stopwords = set(STOPWORDS)
stopwords.update(stop_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-85a41ef1ac64> in <module>
#       1 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#       2 stopwords = set(STOPWORDS)
# ----> 3 stopwords.update(stop_words)
#
# NameError: name 'stop_words' is not defined

# %%
# generate word cloud for high price group
wordcloud = WordCloud(background_color='white', max_words=1000, contour_width=3,contour_color='firebrick', 
                      stopwords = stopwords)

wordcloud.generate(p_words[3])
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# generate word cloud for low price group
wordcloud = WordCloud(background_color='white', max_words=1000, contour_width=3,contour_color='firebrick', 
                      stopwords = stopwords)

wordcloud.generate(p_words[0])
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# generate word cloud for downtown
wordcloud = WordCloud(background_color='white', max_words=1000, contour_width=3,contour_color='firebrick', 
                      stopwords = stopwords)

wordcloud.generate(n_words[15])
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# generate word cloud for Roxbury
wordcloud = WordCloud(background_color='white', max_words=1000, contour_width=3,contour_color='firebrick', 
                      stopwords = stopwords)

wordcloud.generate(n_words[8])
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Model Selection

# %% [markdown]
# ### Feature selection and Linear model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

# %%
# get the feature and label
X = df_mod.drop('price', axis=1)
y = df_mod['price']

# %%
X.shape
# Out:
# (3463, 102)

# %%
# There are two many features, let's select top 30 features with REF model
n = np.arange(5, 100, 5)
model = LinearRegression()
R2 = []
#Initializing RFE model
for num in n:
    rfe = RFE(model, num)
    #Transforming data using RFE
    X_rfe = rfe.fit_transform(X,y)  
    #Fitting the data to model
    model.fit(X_rfe,y)
    # generate new feature matrix
    X_new = X.iloc[:,rfe.support_]
    # split training and testing model
    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)
    # fit the data
    lm = LinearRegression()
    lm.fit(X_train, y_train)
    pred = lm.predict(X_test)
    R2.append(metrics.r2_score(y_test, pred))

# %%
ind = np.array(R2).argmax()
f_n = n[ind]
rfe = RFE(model, f_n)
X_rfe = rfe.fit_transform(X,y) 
model.fit(X_rfe,y)
X_new = X.iloc[:,rfe.support_]
print('{} features are selected'.format(f_n))
# Out:
# 95 features are selected

# %%
# split training and testing model
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=42)

# %%
# fit the data
lm = LinearRegression()
lm.fit(X_train, y_train)
pred = lm.predict(X_test)

# %%
# evaluate
mse = metrics.mean_squared_error(y_test, pred)
r_square = metrics.r2_score(y_test, pred)

print('Mean absolute error is {}'.format(mse))
print('R^2 is {}'.format(r_square))
# Out:
# Mean absolute error is 2599.759883065742
# R^2 is 0.6675173286542568

# %%
# create a function to visualize the distribution of the prediction and the test
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    plt.figure(figsize=(10, 8))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)
    plt.title(Title)
    plt.xlabel('Price (dollars)')
    plt.show()
    plt.close()

# %%
# Visualize the results
DistributionPlot(y_test, pred, 'Actual Values (Train)', 'Predicted Values (Train)', 
                 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution')

# %% [markdown]
# ### Cross Validation

# %%
Rcross = cross_val_score(lm, X_new, y, cv=10)
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.5060307082542456 and the standard deviation is 0.14522003374178225

# %% [markdown]
# ### Ridge Regression

# %%
# screen ridge model
RR_square = []
RR_train = []
alpha = [0.0001, 0.001, 0.1, 1, 10, 20]
for a in alpha:
    RigeModel = Ridge(alpha=a) 
    RigeModel.fit(X_train, y_train)
    RR_square.append(RigeModel.score(X_test, y_test))
    RR_train.append(RigeModel.score(X_train, y_train))

# %%
# visualize
plt.figure(figsize=(8, 5))
plt.plot(alpha,RR_square, label='validation data')
plt.plot(alpha,RR_train, 'r', label='training Data')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.ylim(0.5, 0.8)
plt.legend();

# %%
# Choose a ridge
RigeModel = Ridge(alpha=5) 
RigeModel.fit(X_train, y_train)
rr_pred = RigeModel.predict(X_test)
print('r2 score is: {}'.format(RigeModel.score(X_test, y_test)))
# Out:
# r2 score is: 0.6685482044775237

# %%
# Visualize the results
DistributionPlot(y_test, rr_pred, 'Actual Values (Train)', 'Predicted Values (Train)', 
                 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution')

# %% [markdown]
# We can see that ridge only slightly improve the model...

# %% [markdown]
# # Conclustions

# %%
coef_df = pd.DataFrame(data=list(lm.coef_), index=X_new.columns).reset_index().rename(columns={'index': 'Var', 0: 'Coef'})
# Out:
#                                                Var        Coef
# 66                             property_type_Other   74.516958
# 39                 neighbourhood_cleansed_Downtown   49.588029
# 52  neighbourhood_cleansed_South Boston Waterfront   46.971290
# 63                        property_type_Guesthouse   43.671124
# 37                neighbourhood_cleansed_Chinatown   43.109742
# ..                                             ...         ...
# 42                neighbourhood_cleansed_Hyde Park  -44.392399
# 46                 neighbourhood_cleansed_Mattapan  -46.885652
# 49               neighbourhood_cleansed_Roslindale  -53.451332
# 61                              property_type_Dorm  -56.278153
# 59                         property_type_Camper/RV -150.428664
#
# [95 rows x 2 columns]

# %% [markdown]
# 1. According to our model, every additional bedroom will cost extra 28.5 dollars, while each additional bathroom will cost extra 2.3 dollars. Each additional guests will cost 6 dollars more.
#
# 2. Real bed costs more than alternative options.
#
# 3. Neighbourhood areas strongly bias the price, which will be plot next.
#
# 4. Superhosts' listings are 6 dollars more expensive on average.
#
# 5. Property types strongly affect the price. For example: a camp/RV will cost 150 dollars less on average but a boat will cost 39.7 dollars more on average.
#
# 6. Entire room on average will cost 76.6 more than a shared-room.
#
# 7. In general, the more strict the cacellation policy is, the more expensive the listing will be. Maybe listings have strict cancellation policy are tend to be more expensive and popular.

# %%
# Predicted prive VS. actural price 
plt.figure(figsize=(10,5))
sns.regplot(x=y_test, y=rr_pred, color=sns.color_palette()[0])
plt.xlim(0, 430)
plt.title('Predict Model', fontsize=14)
plt.xlabel('Test Data', fontsize=12)
plt.ylabel('Predictions', fontsize=12);

# %%
# get the neighboorhood
neighborhoods = coef_df[coef_df.Var.str.contains('neighbourhood')].sort_values(by='Coef', ascending=False)
neighborhoods['Var'] = neighborhoods['Var'].apply(lambda x: x.split('_')[2])
neighborhoods
# Out:
#                         Var       Coef
# 39                 Downtown  49.588029
# 52  South Boston Waterfront  46.971290
# 37                Chinatown  43.109742
# 32                 Back Bay  42.973703
# 34              Beacon Hill  39.811945
# 33              Bay Village  32.039473
# 53                South End  30.382685
# 41                   Fenway  24.760924
# 48                North End  20.184617
# 44         Leather District  19.324325
# 36              Charlestown  10.246678
# 54                 West End   5.330457
# 45    Longwood Medical Area   0.392821
# 51             South Boston  -3.488365
# 50                  Roxbury -15.784458
# 47             Mission Hill -20.851222
# 40              East Boston -21.699636
# 31                  Allston -23.187785
# 35                 Brighton -25.091446
# 43            Jamaica Plain -26.336794
# 38               Dorchester -41.875058
# 55             West Roxbury -42.072541
# 42                Hyde Park -44.392399
# 46                 Mattapan -46.885652
# 49               Roslindale -53.451332

# %%
# Visualize neighborhood effect on price
plt.figure(figsize=(12, 8))
sns.barplot(data=neighborhoods, x='Coef', y='Var', palette='Blues_d')
plt.xlabel('Relative Price (dollars)', fontsize=12)
plt.ylabel('Neighborhood', fontsize=12)
plt.title("Neighborhoods' Effects on Predicted Price", fontsize=14);

# %%
# get the neighboorhood
property_type = coef_df[coef_df.Var.str.contains('property_type')].sort_values(by='Coef', ascending=False)
property_type['Var'] = property_type['Var'].apply(lambda x: x.split('_')[2])
property_type
# Out:
#                 Var        Coef
# 66            Other   74.516958
# 63       Guesthouse   43.671124
# 58             Boat   39.692919
# 68            Villa   33.708405
# 57  Bed & Breakfast   16.376557
# 65             Loft    8.342525
# 67        Townhouse    8.005623
# 60      Condominium    6.027359
# 56        Apartment   -1.431608
# 64            House   -1.825556
# 62     Entire Floor  -30.749654
# 61             Dorm  -56.278153
# 59        Camper/RV -150.428664

# %%
# Visualize property_type effect on price
plt.figure(figsize=(12, 8))
sns.barplot(data=property_type, x='Coef', y='Var', palette='Blues_d')
plt.xlabel('Relative Price (dollars)', fontsize=12)
plt.ylabel('Property Type', fontsize=12)
plt.title("Property Type's Effects on Predicted Price", fontsize=14);
